# %%
import pandas as pd    
import matplotlib.pyplot as plt    
import seaborn as sns   
import numpy as np

# %%
import pandas as pd

athelits = pd.read_csv("olympics dataset/athlete_events.csv")
region = pd.read_csv("olympics dataset/noc_regions.csv")
athletes.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       3 athelits = pd.read_csv("olympics dataset/athlete_events.csv")
#       4 region = pd.read_csv("olympics dataset/noc_regions.csv")
# ----> 5 athletes.head()
#
# NameError: name 'athletes' is not defined

# %%
athelits=pd.read_csv("olympics dataset/athlete_events.csv")
athelits.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
region.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
df=pd.merge(athelits,region,on="NOC")

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# 1      Judo Men's Extra-Lightweight   NaN        China   NaN
# 2           Football Men's Football   NaN      Denmark   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold      Denmark   NaN
# 4  Speed Skating Women's 500 metres   NaN  Netherlands   NaN

# %%
df.duplicated().sum()
# Out:
# 1385

# %%
df.shape
# Out:
# (270767, 17)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (269382, 17)

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9303
# Height     58726
# Weight     61437
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     229619
# region        21
# notes     264347
# dtype: int64

# %%
df["Medal"].unique()
# Out:
# array([nan, 'Gold', 'Bronze', 'Silver'], dtype=object)

# %%
df["Medal"].fillna("No_medal",inplace=True)
# Out:
# C:\Users\nandi\AppData\Local\Temp\ipykernel_17372\2034173955.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Medal"].fillna("No_medal",inplace=True)

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9303
# Height     58726
# Weight     61437
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     229619
# region        21
# notes     264347
# dtype: int64

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# 1      Judo Men's Extra-Lightweight   NaN        China   NaN
# 2           Football Men's Football   NaN      Denmark   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold      Denmark   NaN
# 4  Speed Skating Women's 500 metres   NaN  Netherlands   NaN

# %%
df["Season"].value_counts()
# Out:
# Season
# Summer    220818
# Winter     48564
# Name: count, dtype: int64

# %%
summer=df[df["Season"]=="Summer"]
winter=df[df["Season"]=="Winter"]

# %%
summer.shape
# Out:
# (220818, 17)

# %%
winter.shape
# Out:
# (48564, 17)

# %%
# season wise meadal tally

# %%
medal_count_summer=summer.groupby(["NOC","Medal"]).size().reset_index(name="count")

# %%
medal_count_summer
# Out:
#      NOC     Medal  count
# 0    AFG    Bronze      2
# 1    AFG  No_medal    124
# 2    AHO  No_medal     73
# 3    AHO    Silver      1
# 4    ALB  No_medal     63
# ..   ...       ...    ...
# 579  ZAM    Silver      1
# 580  ZIM    Bronze      1
# 581  ZIM      Gold     17
# 582  ZIM  No_medal    287
# 583  ZIM    Silver      4
#
# [584 rows x 3 columns]

# %%
medal_pivot_summer=medal_count_summer.pivot(index="NOC",columns="Medal",values="count").fillna(0)

# %%
medal_pivot_summer
# Out:
# Medal  Bronze   Gold  Silver
# NOC
# AFG       2.0    0.0     0.0
# AHO       0.0    0.0     1.0
# ALG       8.0    5.0     4.0
# ANZ       5.0   20.0     4.0
# ARG      91.0   91.0    92.0
# ..        ...    ...     ...
# VIE       0.0    1.0     3.0
# WIF       5.0    0.0     0.0
# YUG      92.0  130.0   161.0
# ZAM       1.0    0.0     1.0
# ZIM       1.0   17.0     4.0
#
# [146 rows x 3 columns]

# %%
medal_pivot_summer=medal_pivot_summer.astype(int)

# %%
medal_pivot_summer
# Out:
# Medal  Bronze   Gold  Silver
# NOC
# AFG       2.0    0.0     0.0
# AHO       0.0    0.0     1.0
# ALG       8.0    5.0     4.0
# ANZ       5.0   20.0     4.0
# ARG      91.0   91.0    92.0
# ..        ...    ...     ...
# VIE       0.0    1.0     3.0
# WIF       5.0    0.0     0.0
# YUG      92.0  130.0   161.0
# ZAM       1.0    0.0     1.0
# ZIM       1.0   17.0     4.0
#
# [146 rows x 3 columns]

# %%
medal_pivot_summer["Total_medal"] = medal_pivot_summer[["Gold", "Silver", "Bronze"]].sum(axis=1)

# %%
medal_pivot_summer
# Out:
# Medal  Bronze   Gold  Silver  Total_medal
# NOC
# AFG       2.0    0.0     0.0          2.0
# AHO       0.0    0.0     1.0          1.0
# ALG       8.0    5.0     4.0         17.0
# ANZ       5.0   20.0     4.0         29.0
# ARG      91.0   91.0    92.0        274.0
# ..        ...    ...     ...          ...
# VIE       0.0    1.0     3.0          4.0
# WIF       5.0    0.0     0.0          5.0
# YUG      92.0  130.0   161.0        383.0
# ZAM       1.0    0.0     1.0          2.0
# ZIM       1.0   17.0     4.0         22.0
#
# [146 rows x 4 columns]

# %%
medal_pivot_summer.sort_values(by=["Gold", "Silver", "Bronze"], ascending=False)
# Out:
# Medal  Bronze  Gold  No_medal  Silver  Total_medal
# NOC
# USA      1197  2472     10062    1333         5002
# URS       596   832      2559     635         2063
# GBR       620   636      8932     729         1985
# GER       649   592      5843     538         1779
# ITA       454   518      6771     474         1446
# ..        ...   ...       ...     ...          ...
# VIN         0     0        42       0            0
# VNM         0     0        62       0            0
# YAR         0     0        11       0            0
# YEM         0     0        32       0            0
# YMD         0     0         5       0            0
#
# [229 rows x 5 columns]

# %%
medal_pivot_summer.sort_values(by=["Gold", "Silver", "Bronze"], ascending=False).head(30)
# Out:
# Medal  Bronze    Gold  Silver  Total_medal
# NOC
# USA    1197.0  2472.0  1333.0       5002.0
# URS     596.0   832.0   635.0       2063.0
# GBR     620.0   635.0   729.0       1984.0
# GER     649.0   592.0   538.0       1779.0
# ITA     454.0   518.0   474.0       1446.0
# FRA     587.0   463.0   567.0       1617.0
# HUN     363.0   432.0   328.0       1123.0
# SWE     358.0   354.0   396.0       1108.0
# AUS     510.0   342.0   452.0       1304.0
# GDR     227.0   339.0   277.0        843.0
# CHN     258.0   334.0   317.0        909.0
# RUS     331.0   296.0   278.0        905.0
# NED     371.0   245.0   302.0        918.0
# JPN     333.0   230.0   287.0        850.0
# NOR     167.0   227.0   196.0        590.0
# DEN     177.0   179.0   236.0        592.0
# KOR     175.0   171.0   206.0        552.0
# CUB     116.0   164.0   129.0        409.0
# ROU     290.0   161.0   200.0        651.0
# CAN     344.0   158.0   239.0        741.0
# FRG     188.0   144.0   172.0        504.0
# FIN     217.0   132.0   125.0        474.0
# IND      40.0   131.0    19.0        190.0
# YUG      92.0   130.0   161.0        383.0
# POL     242.0   111.0   185.0        538.0
# ESP     135.0   109.0   243.0        487.0
# BRA     191.0   109.0   175.0        475.0
# SUI     139.0    99.0   178.0        416.0
# BEL     166.0    96.0   193.0        455.0
# EUN      67.0    92.0    61.0        220.0

# %%
summer.head()
# Out:
#     ID                                Name Sex   Age  Height  Weight  \
# 0    1                           A Dijiang   M  24.0   180.0    80.0
# 1    2                            A Lamusi   M  23.0   170.0    60.0
# 2    3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3    4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26   8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
#
#               Team  NOC        Games  Year  Season         City       Sport  \
# 0            China  CHN  1992 Summer  1992  Summer    Barcelona  Basketball
# 1            China  CHN  2012 Summer  2012  Summer       London        Judo
# 2          Denmark  DEN  1920 Summer  1920  Summer    Antwerpen    Football
# 3   Denmark/Sweden  DEN  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 26     Netherlands  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                            Event Medal       region notes
# 0    Basketball Men's Basketball   NaN        China   NaN
# 1   Judo Men's Extra-Lightweight   NaN        China   NaN
# 2        Football Men's Football   NaN      Denmark   NaN
# 3    Tug-Of-War Men's Tug-Of-War  Gold      Denmark   NaN
# 26  Athletics Women's 100 metres   NaN  Netherlands   NaN

# %%
summer=summer.drop_duplicates(subset=["Team","NOC","Games","Year","City","Sport","Event"])

# %%
summer.shape
# Out:
# (98657, 17)

# %%
winter=winter.drop_duplicates(subset=["Team","NOC","Games","Year","City","Sport","Event"])

# %%
winter.shape
# Out:
# (16956, 17)

# %%
medal_count_winter=winter.groupby(["NOC","Medal"]).size().reset_index(name="count")

# %%
medal_pivot_winter=medal_count_winter.pivot(index="NOC",columns="Medal",values="count").fillna(0)

# %%
medal_pivot_winter=medal_pivot_winter.astype(int)

# %%
medal_pivot_winter
# Out:
# Medal  Bronze  Gold  Silver
# NOC
# AUS         4     5       3
# AUT        24    21      31
# BEL         3     1       1
# BLR         3     3       2
# BUL         0     1       1
# CAN        25    43      34
# CHN        12     5       8
# CRO         1     1       5
# CZE         5     6       5
# DEN         0     0       1
# ESP         0     1       0
# EST         0     1       0
# EUN         4     5       2
# FIN        26    15      30
# FRA        25     8      14
# FRG        11     6       8
# GBR         9     8       3
# GDR        19    19      17
# GER        36    39      38
# HUN         4     0       2
# IND         0     1       0
# ITA        25    19      17
# JPN         7     7       7
# KAZ         1     0       0
# KOR         1    14       7
# LAT         2     0       4
# LIE         2     0       1
# LUX         0     0       2
# NED        11    10      12
# NEP         0     1       0
# NOR        48    58      43
# NZL         0     0       1
# POL         4     3       3
# PRK         1     0       0
# ROU         1     0       0
# RUS        21    28      22
# SLO         3     0       0
# SUI        27    18      22
# SVK         1     0       1
# SWE        31    23      22
# TCH        11     1       6
# UKR         1     2       1
# URS        24    46      24
# USA        44    39      48
# UZB         0     1       0
# YUG         1     0       1

# %%
medal_pivot_winter["Total_medal"] = medal_pivot_winter[["Gold", "Silver", "Bronze"]].sum(axis=1)

# %%
medal_pivot_winter.sort_values(by=["Gold", "Silver", "Bronze"], ascending=False).head(30)
# Out:
# Medal  Bronze  Gold  No_medal  Silver
# NOC
# NOR        48    58       529      43
# URS        24    46       216      24
# CAN        25    43       770      34
# USA        44    39       894      48
# GER        36    39       534      38
# RUS        21    28       388      22
# SWE        31    23       560      22
# AUT        24    21       594      31
# ITA        25    19       739      17
# GDR        19    19       133      17
# SUI        27    18       556      22
# FIN        26    15       442      30
# KOR         1    14       330       7
# NED        11    10       202      12
# FRA        25     8       640      14
# GBR         9     8       513       3
# JPN         7     7       688       7
# FRG        11     6       209       8
# CZE         5     6       280       5
# CHN        12     5       296       8
# AUS         4     5       312       3
# EUN         4     5        48       2
# POL         4     3       474       3
# BLR         3     3       174       2
# UKR         1     2       245       1
# TCH        11     1       285       6
# CRO         1     1        87       5
# BEL         3     1       117       1
# BUL         0     1       270       1
# ESP         0     1       180       0

# %%
# country wise medal tally

# %%
medal_pivot_summer["Total_medal"] = medal_pivot_summer[["Gold", "Silver", "Bronze"]].sum(axis=1)

# %%
import pandas as pd

athelits = pd.read_csv("olympics dataset/athlete_events.csv")
region = pd.read_csv("olympics dataset/noc_regions.csv")
athelits.head()
region.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
medal_pivot_summer["Total_medal"] = medal_pivot_summer[["Gold", "Silver", "Bronze"]].sum(axis=1)

# %%
medal_pivot_summer
# Out:
# Medal  Bronze   Gold  Silver  Total_medal
# NOC
# AFG       2.0    0.0     0.0          2.0
# AHO       0.0    0.0     1.0          1.0
# ALG       8.0    5.0     4.0         17.0
# ANZ       5.0   20.0     4.0         29.0
# ARG      91.0   91.0    92.0        274.0
# ..        ...    ...     ...          ...
# VIE       0.0    1.0     3.0          4.0
# WIF       5.0    0.0     0.0          5.0
# YUG      92.0  130.0   161.0        383.0
# ZAM       1.0    0.0     1.0          2.0
# ZIM       1.0   17.0     4.0         22.0
#
# [146 rows x 4 columns]

# %%
def fetch_noc(noc,pivot_table):
    if noc in pivot_table.index:
        details={
            "Gold": pivot_table.loc[noc,"Gold"],
            "Silver": pivot_table.loc[noc,"Silver"],
            "Bronze": pivot_table.loc[noc,"Bronze"],
            "Total_Medal": pivot_table.loc[noc,"Total_medal"]
        }
        return details
    else:
        print("No noc exits")

# %%
fetch_noc("IND",medal_pivot_summer)
# Out:
# {'Gold': 131.0, 'Silver': 19.0, 'Bronze': 40.0, 'Total_Medal': 190.0}

# %%
# Year Wise searchingsu

# %%
summer.shape
# Out:
# (98657, 17)

# %%
summer.head()
# Out:
#     ID                                Name Sex   Age  Height  Weight  \
# 0    1                           A Dijiang   M  24.0   180.0    80.0
# 1    2                            A Lamusi   M  23.0   170.0    60.0
# 2    3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3    4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26   8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
#
#               Team  NOC        Games  Year  Season         City       Sport  \
# 0            China  CHN  1992 Summer  1992  Summer    Barcelona  Basketball
# 1            China  CHN  2012 Summer  2012  Summer       London        Judo
# 2          Denmark  DEN  1920 Summer  1920  Summer    Antwerpen    Football
# 3   Denmark/Sweden  DEN  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 26     Netherlands  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                            Event Medal       region notes
# 0    Basketball Men's Basketball   NaN        China   NaN
# 1   Judo Men's Extra-Lightweight   NaN        China   NaN
# 2        Football Men's Football   NaN      Denmark   NaN
# 3    Tug-Of-War Men's Tug-Of-War  Gold      Denmark   NaN
# 26  Athletics Women's 100 metres   NaN  Netherlands   NaN

# %%
summer.isnull().sum()
# Out:
# ID            0
# Name          0
# Sex           0
# Age        3119
# Height    17827
# Weight    18182
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal     87265
# region       20
# notes     96593
# dtype: int64

# %%
summer.dropna(subset=["region"],inplace=True)

# %%
summer.shape
# Out:
# (98637, 17)

# %%
medals_count=summer.groupby(["Year","region","Medal"]).size().unstack(fill_value=0)

# %%
medals_count
# Out:
# Medal            Bronze  Gold  Silver
# Year region
# 1896 Australia        1     2       0
#      Austria          2     2       1
#      Denmark          3     1       2
#      France           2     1       4
#      Germany          1     4       1
# ...                 ...   ...     ...
# 2016 Tajikistan       0     1       0
#      Grenada          0     0       1
#      Fiji             0     1       0
#      Jordan           0     1       0
#      Kosovo           0     1       0
#
# [1224 rows x 3 columns]

# %%
medals_count=medals_count.reset_index()

# %%
medals_count
# Out:
# Medal  index  Year      region  Bronze  Gold  Silver
# 0          0  1896   Australia       1     2       0
# 1          1  1896     Austria       2     2       1
# 2          2  1896     Denmark       3     1       2
# 3          3  1896      France       2     1       4
# 4          4  1896     Germany       1     4       1
# ...      ...   ...         ...     ...   ...     ...
# 1219    1219  2016  Tajikistan       0     1       0
# 1220    1220  2016     Grenada       0     0       1
# 1221    1221  2016        Fiji       0     1       0
# 1222    1222  2016      Jordan       0     1       0
# 1223    1223  2016      Kosovo       0     1       0
#
# [1224 rows x 6 columns]

# %%
medals_count["Total_Medal"]=medals_count["Gold"] + medals_count["Silver"]+ medals_count["Bronze"]

# %%
medals_count
# Out:
# Medal  index  Year      region  Bronze  Gold  Silver  Total_Medal
# 0          0  1896   Australia       1     2       0            3
# 1          1  1896     Austria       2     2       1            5
# 2          2  1896     Denmark       3     1       2            6
# 3          3  1896      France       2     1       4            7
# 4          4  1896     Germany       1     4       1            6
# ...      ...   ...         ...     ...   ...     ...          ...
# 1219    1219  2016  Tajikistan       0     1       0            1
# 1220    1220  2016     Grenada       0     0       1            1
# 1221    1221  2016        Fiji       0     1       0            1
# 1222    1222  2016      Jordan       0     1       0            1
# 1223    1223  2016      Kosovo       0     1       0            1
#
# [1224 rows x 7 columns]

# %%
def plot_medals(year,country,df):
    filtered_df=df[(df["Year"]==year)&(df["region"]==country)]
    gold=filtered_df["Gold"].values[0]
    silver=filtered_df["Silver"].values[0]
    bronze=filtered_df["Bronze"].values[0]
    total_medal=filtered_df["Total_Medal"].values[0]
    fig,ax=plt.subplots()
    medals=["Gold","Silver","Bronze","Total_Medals"]
    counts=[gold,silver,bronze,total_medal]
    ax.bar(medals,counts,color=["gold","silver","brown","green"])
    plt.show

# %%
plot_medals(1896,"Germany",medals_count)

# %%
# year wise progress

# %%
medals_count
# Out:
# Medal  index  Year      region  Bronze  Gold  Silver  Total_Medal
# 0          0  1896   Australia       1     2       0            3
# 1          1  1896     Austria       2     2       1            5
# 2          2  1896     Denmark       3     1       2            6
# 3          3  1896      France       2     1       4            7
# 4          4  1896     Germany       1     4       1            6
# ...      ...   ...         ...     ...   ...     ...          ...
# 1219    1219  2016  Tajikistan       0     1       0            1
# 1220    1220  2016     Grenada       0     0       1            1
# 1221    1221  2016        Fiji       0     1       0            1
# 1222    1222  2016      Jordan       0     1       0            1
# 1223    1223  2016      Kosovo       0     1       0            1
#
# [1224 rows x 7 columns]

# %%
def plot_year_progress(country,df):
    filtered_df=df[df["region"]==country]
    fig,ax=plt.subplots()
    ax.plot(filtered_df["Year"],filtered_df["Gold"],color="gold",label="GOLD",marker="o",linestyle=".")
    ax.plot(filtered_df["Year"],filtered_df["Silver"],color="silver",label="SILVER",marker="o",linestyle=".")
    ax.plot(filtered_df["Year"],filtered_df["Bronze"],color="brown",label="BRONZE",marker="o",linestyle=".")
    ax.plot(filtered_df["Year"],filtered_df["Total_Medal"],color="green",label="TOTAL_MEDALS",marker="o",linestyle=".")
    ax.legend()
    plt.show()

# %%
plot_year_progress("USA",medals_count)

# %%
summer.head()
# Out:
#     ID                                Name Sex   Age  Height  Weight  \
# 0    1                           A Dijiang   M  24.0   180.0    80.0
# 1    2                            A Lamusi   M  23.0   170.0    60.0
# 2    3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3    4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26   8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
#
#               Team  NOC        Games  Year  Season         City       Sport  \
# 0            China  CHN  1992 Summer  1992  Summer    Barcelona  Basketball
# 1            China  CHN  2012 Summer  2012  Summer       London        Judo
# 2          Denmark  DEN  1920 Summer  1920  Summer    Antwerpen    Football
# 3   Denmark/Sweden  DEN  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 26     Netherlands  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                            Event Medal       region notes
# 0    Basketball Men's Basketball   NaN        China   NaN
# 1   Judo Men's Extra-Lightweight   NaN        China   NaN
# 2        Football Men's Football   NaN      Denmark   NaN
# 3    Tug-Of-War Men's Tug-Of-War  Gold      Denmark   NaN
# 26  Athletics Women's 100 metres   NaN  Netherlands   NaN
